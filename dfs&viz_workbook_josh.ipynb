# %%
import pandas as pd
import numpy as np
import json
import ast 
import io

# %%
df = pd.read_csv('imdb_rt_combined_edited.csv', index_col=0)

# %%
df.head()
# Out:
#               title  network  imdb_rating  num_imdb_ratings  rt_critic_rating  \
# 0  La Casa de Papel  Netflix          8.5            215007              91.0
# 1             Ozark  Netflix          8.4            136710              81.0
# 2        Tiger King  Netflix          7.8             33700              86.0
# 3         Westworld      HBO          8.7            388252              85.0
# 4  The Walking Dead      AMC          8.2            821809              81.0
#
#    rt_audience_rating                                      genres tv_rating  \
# 0                82.0  ['action', 'crime', 'mystery', 'thriller']     TV-MA
# 1                91.0              ['crime', 'drama', 'thriller']     TV-MA
# 2                86.0                    ['documentary', 'crime']     TV-MA
# 3                80.0   ['drama', 'mystery', 'sci-fi', 'western']     TV-MA
# 4                78.0             ['drama', 'horror', 'thriller']     TV-MA
#
# ...

# %%
df = df.sort_values(['imdb_rating', 'rt_critic_rating', 'num_imdb_ratings'], ascending=False)

# %%
df[df['num_imdb_ratings'] < 10000]
# Out:
#                              title          network  imdb_rating  \
# 163               One Strange Rock              NGC          8.7
# 177         The Promised Neverland          Aniplex          8.6
# 173       Justice League Unlimited  Cartoon Network          8.6
# 267                   Detectorists            Acorn          8.5
# 251            Yes, Prime Minister          BBC Two          8.5
# 228                          Umbre              HBO          8.5
# 310                    Delhi Crime          Netflix          8.4
# 32                            Devs             Hulu          7.9
# 68   Zoey's Extraordinary Playlist              NBC          7.9
# 74                The English Game          Netflix          7.7
# 24                    All American               CW          7.6
# 39                Home Before Dark        Apple TV+          7.6
# 20         Little Fires Everywhere             Hulu          7.6
# ...

# %%
df['num_imdb_ratings'].describe()
# Out:
# count    2.470000e+02
# mean     1.357822e+05
# std      1.935288e+05
# min      8.630000e+02
# 25%      2.480300e+04
# 50%      6.865100e+04
# 75%      1.732325e+05
# max      1.658978e+06
# Name: num_imdb_ratings, dtype: float64

# %%
df['release_year'].value_counts()
# Out:
# 2018    18
# 2017    16
# 2020    15
# 2014    15
# 2016    14
# 2019    14
# 2015    12
# 2013    12
# 2010    12
# 2005    11
# 2011    11
# 2009     8
# 2003     7
# 2006     7
# 2012     7
# 2004     6
# 1999     6
# 2008     5
# 1989     5
# 2002     4
# 2001     4
# 1997     4
# 2007     3
# 2000     3
# 1986     3
# 1992     2
# 1987     2
# 1990     2
# 1998     2
# 1993     2
# 1995     2
# 1994     1
# 1988     1
# 1996     1
# 1985     1
# 1984     1
# 1981     1
# 1980     1
# 1976     1
# 1975     1
# 1973     1
# 1969     1
# 1959     1
# 1955     1
# Name: release_year, dtype: int64

# %%
df[df['release_year'] == 1975]
# Out:
#              title  network  imdb_rating  num_imdb_ratings  rt_critic_rating  \
# 145  Fawlty Towers  BBC Two          8.7             80669               100
#
#      rt_audience_rating      genres tv_rating  release_year  runtime_mins  \
# 145                92.0  ['comedy']     TV-PG          1975            30
#
#     rt_season_ratings                               imdb_url
# 145        [100, nan]  https://www.imdb.com/title/tt0072500/

# %%
df['runtime_mins'] = df['runtime_mins'].astype('int64')

# %%
df_num_ratings = df.sort_values('num_imdb_ratings', ascending = False)

# %%
json.loads(df.iloc[20]['rt_season_ratings'])
# Out:
# [87, 62, 85]

# %%
ast.literal_eval(df.iloc[20]['rt_season_ratings'])
# Out:
# [87, 62, 85]

# %%
df['rt_season_ratings'].value_counts()
# Out:
# [nan]                                       12
# [100]                                       11
# [nan, nan, nan, nan, nan, nan, nan, nan]     7
# [nan, nan]                                   5
# [96]                                         4
#                                             ..
# [100, 88, nan]                               1
# [100, 93, 80, 81, 88, 78, 80, 84]            1
# [80, 92, 97]                                 1
# [94, 89, 81, nan]                            1
# [82, 83, 93, 90, 100, 100, nan]              1
# Name: rt_season_ratings, Length: 190, dtype: int64

# %%
def ast_loader(x):
    try:
        list(ast.literal_eval(x))
    except ValueError as e:
        print(e)
        pass

# %%
type(df.iloc[0]['rt_season_ratings'])
# Out:
# str

# %%
df.rt_season_ratings.apply(lambda x: copy_df_det['countries']=copy_df_det['production_countries'].apply(lambda x: ast.literal_eval(x)))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-84-0d8073f12217> in <module>
# ----> 1 df.rt_season_ratings.apply(lambda x: json.loads(x))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-84-0d8073f12217> in <lambda>(x)
# ----> 1 df.rt_season_ratings.apply(lambda x: json.loads(x))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
df['rt_season_ratings'].apply(lambda x: json.loads(x))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-74-e80d48bb6d94> in <module>
# ----> 1 df['rt_season_ratings'].apply(lambda x: json.loads(x))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-74-e80d48bb6d94> in <lambda>(x)
# ----> 1 df['rt_season_ratings'].apply(lambda x: json.loads(x))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
df_num_ratings.head(20)
# Out:
#                      title   network  imdb_rating  num_imdb_ratings  \
# 8          Game of Thrones       HBO          9.3           1658978
# 10            Breaking Bad       AMC          9.5           1332330
# 4         The Walking Dead       AMC          8.2            821809
# 73                Sherlock       PBS          9.1            754631
# 28                 Friends       NBC          8.9            750880
# 25         Stranger Things   Netflix          8.8            725728
# 71     The Big Bang Theory       CBS          8.1            684180
# 204                 Dexter  Showtime          8.6            619651
# 84   How I Met Your Mother       CBS          8.3            569198
# 77                    Lost       ABC          8.3            472317
# 72          True Detective       HBO          9.0            471428
# 151         House of Cards   Netflix          8.7            448383
# 47            Prison Break       FOX          8.3            448235
# ...

# %%
for element in df['rt_season_ratings']:
    for i in range(len(element)):
        element[i].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-8361552546a5> in <module>
#       1 for element in df['rt_season_ratings']:
#       2     for i in range(len(element)):
# ----> 3         element[i].plot.bar()
#
# AttributeError: 'str' object has no attribute 'plot'

# %%
df3 = pd.read_csv('rt_info.csv', index_col=0)
df3.head()
# Out:
#               title  rt_critic_rating  rt_audience_rating  network  \
# 0  La Casa de Papel              91.0                82.0  Netflix
# 1             Ozark              81.0                91.0  Netflix
# 2        Tiger King              86.0                86.0  Netflix
# 3         Westworld              85.0                80.0      HBO
# 4  The Walking Dead              81.0                78.0      AMC
#
#                      season_ratings
# 0               [nan, 100, 100, 75]
# 1                      [70, 76, 97]
# 2                              [86]
# 3                      [87, 86, 83]
# 4  [88, 83, 90, 76, 64, 64, 91, 91]

# %%
df3.iloc[0]['season_ratings']
# Out:
# '[nan, 100, 100, 75]'

# %%
dataframe turned my lists into strings

# %%
pd.eval(df['rt_season_ratings'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     191             assert not is_local and not self.has_resolvers
# --> 192             return self.scope[key]
#     193         except KeyError:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/collections/__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/collections/__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'nan'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.head()
# Out:
#                 title            network  imdb_rating  num_imdb_ratings  \
# 100   Planet Earth II        BBC America          9.5             86650
# 10       Breaking Bad                AMC          9.5           1332330
# 65          Chernobyl                HBO          9.4            442470
# 101      Planet Earth  Discovery Channel          9.4            158876
# 102  Band of Brothers                HBO          9.4            349246
#
#      rt_critic_rating  rt_audience_rating  \
# 100               100                97.0
# 10                 96                98.0
# 65                 96                98.0
# 101                95               100.0
# 102                94                98.0
#
#                                     genres tv_rating  release_year  \
# 100                        ['documentary']      TV-G          2016
# 10          ['crime', 'drama', 'thriller']     TV-MA          2008
# 65        ['drama', 'history', 'thriller']     TV-MA          2019
# ...

# %%
test_dict = {df.iloc[i]['title']: df.iloc[i]['genres'] for i in range(len(df))}

# %%
len(df)
# Out:
# 247

# %%
{k: json.loads(v) for k,v in test_dict.items()}
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-102-3289e441b7d9> in <module>
# ----> 1 {k: json.loads(v) for k,v in test_dict.items()}
#
# <ipython-input-102-3289e441b7d9> in <dictcomp>(.0)
# ----> 1 {k: json.loads(v) for k,v in test_dict.items()}
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# ...

# %%
df.rt_season_ratings.apply(json.loads)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-103-d5456f53fbfa> in <module>
# ----> 1 df.rt_season_ratings.apply(json.loads)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %%
test_dict.values()
# Out:
# dict_values(["['documentary']", "['crime', 'drama', 'thriller']", "['drama', 'history', 'thriller']", "['documentary']", "['action', 'drama', 'history', 'war']", "['documentary']", "['crime', 'drama', 'thriller']", "['documentary']", "['action', 'adventure', 'drama', 'fantasy', 'romance']", "['animation', 'action', 'adventure', 'family', 'fantasy', 'mystery']", "['animation', 'adventure', 'comedy', 'sci-fi']", "['crime', 'drama']", "['animation', 'action', 'adventure', 'comedy', 'drama', 'fantasy', 'sci-fi']", "['documentary', 'history', 'war']", "['documentary', 'history', 'war']", "['crime', 'drama', 'mystery', 'thriller']", "['documentary']", "['drama']", "['animation', 'action', 'adventure', 'family', 'sci-fi']", "['drama', 'fantasy', 'horror', 'mystery', 'sci-fi', 'thriller']", "['crime', 'drama', 'mystery', 'thriller']", "['adventure', 'drama', 'sci-fi']", "['animation', 'crime', 'drama', 'fantasy', 'mystery', 'thriller']", "['animation', 'action', 'adventure', 'drama', 'sci-fi
# ...

# %%
def CustomParser(x):
    import json
    j1 = json.loads(x)
    return j1

# %%
df1 = pd.read_csv('imdb_rt_combined_edited.csv', index_col=0, converters={'rt_season_ratings':json.loads})

# In your case you'll have something like:

# df = pandas.read_csv(f1, converters={'stats':CustomParser},header=0)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-109-b83c857fc649> in <module>
# ----> 1 df1 = pd.read_csv('imdb_rt_combined_edited.csv', index_col=0, converters={'rt_season_ratings':json.loads})
#       2
#       3 # In your case you'll have something like:
#       4
#       5 # df = pandas.read_csv(f1, converters={'stats':CustomParser},header=0)
#
# ...
